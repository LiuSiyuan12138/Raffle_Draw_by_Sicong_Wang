# %%
import pandas as pd

# %%
a=pd.read_csv('1000-1999.csv')

# %%
b=a.sample(n=200).reset_index(drop=True)
b['uid'].astype('str').tolist()
# Out:
# ['6773605184',
#  '2357028661',
#  '5490055493',
#  '6023963753',
#  '5255493362',
#  '3602903620',
#  '6398065315',
#  '2145049800',
#  '6275819248',
#  '6555947355',
#  '6338835958',
#  '6492567335',
#  '5940209630',
#  '5118878402',
#  '6375469199',
#  '6671504773',
#  '5616791753',
#  '3807599049',
#  '5576066611',
#  '6117668779',
#  '5465795324',
#  '6065409690',
#  '1449924283',
#  '6368218879',
#  '2161482974',
#  '2780805464',
#  '2302320033',
#  '6100860090',
#  '5822139787',
#  '5846440588',
#  '3278435674',
#  '6502479080',
#  '6146027601',
#  '6851954437',
#  '6857794413',
#  '6071237850',
#  '6140558777',
#  '5323768875',
#  '6019444049',
#  '2589971053',
#  '6446035636',
#  '6850443016',
#  '1412958352',
#  '2679554143',
#  '5908263177',
#  '5995660915',
#  '1691717853',
#  '2392867731',
#  '2264466843',
#  '5629984443',
#  '5659708780',
#  '6094440608',
#  '2960905413',
#  '6094489169',
#  '3158444804',
#  '3995440453',
#  '6384992374',
#  '5729098695',
# ...

# %%
b=a['sources'].mode().tolist()

# %%
b
# Out:
# ['荣耀Magic2 魔法手机']

# %%
a
# Out:
#     attitudes  comments  have_pic  is_original  reposts        sources  \
# 4      225095    203682         1            1   140863  荣耀Magic2 魔法手机
# 5      184996    104562         1            1    89906  荣耀Magic2 魔法手机
# 6      199024    130410         1            1   144185  荣耀Magic2 魔法手机
# 7      292708     93710         0            0   419044  荣耀Magic2 魔法手机
# 8      232003     36561         0            1   120790  荣耀Magic2 魔法手机
# 9      650688    107953         1            1   282595  荣耀Magic2 魔法手机
# 10     328151     41335         1            1   217429  荣耀Magic2 魔法手机
# 11    7454403   2034000         1            1  5203997   荣耀10 AI变色更潮美
# 12    1128539    301076         0            1  1316611           生日动态
# 13     185626     73336         0            0   102448   荣耀10 AI变色更潮美
#
#                                                 texts  times
# 4   华硕灵耀U 2代\n全面屏笔记本\n看的更宽广\n美才更全面\n双11优惠来袭\n@华硕笔记...   1107
# 5   提前过双11，一起来玩石头剪刀布吧网页链接  #明星猜拳PK#，赢了我就送你专属福利哦~洁婷...   1105
# ...

# %%
d1={'a1':[1],'b1':[2]}
d2={'c1':[3],'d1':[4]}
d3={}
d3.update(d1)
d3.update(d2)
d3
# Out:
# {'a1': [1], 'b1': [2], 'c1': [3], 'd1': [4]}

# %%
a['is_original'].count()
# Out:
# 10

# %%
import numpy as np
a={'original_count': [0], 'have_pic_count': [0], 'total_weibo_count': [0], 'source': [], 'sum_attitudes': [0], 'sum_comments': [0], 'sum_reposts': [0], 'mean_attitudes': [0], 'mean_comments': [0], 'mean_reposts': [0]}
b={'name': ['家里蹲忙的跟狗似的2333'], 'uid': ['2098329887'], 'is_verified': ['False'], '关注人数': [194], 'fan_num': [29], 'gender': ['f'], 'level': [4]}
a.update(b)

# %%
a['original_count'][0]==0
# Out:
# True

# %%
c={'original_count': [0], 'have_pic_count': [0], 'total_weibo_count': [0], 'source': [np.nan], 'sum_attitudes': [0], 'sum_comments': [0], 'sum_reposts': [0], 'mean_attitudes': [0], 'mean_comments': [0], 'mean_reposts': [0], 'name': ['家里蹲忙的跟狗似的2333'], 'uid': ['2098329887'], 'is_verified': ['False'], '关注人数': [194], 'fan_num': [29], 'gender': ['f'], 'level': [4]}

# %%
c
# Out:
# {'original_count': [0],
#  'have_pic_count': [0],
#  'total_weibo_count': [0],
#  'source': [nan],
#  'sum_attitudes': [0],
#  'sum_comments': [0],
#  'sum_reposts': [0],
#  'mean_attitudes': [0],
#  'mean_comments': [0],
#  'mean_reposts': [0],
#  'name': ['家里蹲忙的跟狗似的2333'],
#  'uid': ['2098329887'],
#  'is_verified': ['False'],
#  '关注人数': [194],
#  'fan_num': [29],
#  'gender': ['f'],
#  'level': [4]}

# %%
pd.DataFrame(c)
# Out:
#    fan_num gender  have_pic_count is_verified  level  mean_attitudes  \
# 0       29      f               0       False      4               0
#
#    mean_comments  mean_reposts           name  original_count  source  \
# 0              0             0  家里蹲忙的跟狗似的2333               0     NaN
#
#    sum_attitudes  sum_comments  sum_reposts  total_weibo_count         uid  \
# 0              0             0            0                  0  2098329887
#
#    关注人数
# 0   194

# %%
a=pd.read_csv('sample.csv')

# %%
a
# Out:
#     Unnamed: 0  fan_num gender  have_pic_count  is_verified  level  \
# 0            0       31      f               0        False      4
# 1            1       80      m               1        False     14
# 2            2        1      f               0        False      1
# 3            3       91      f              19        False     14
# 4            4       54      f               0        False      6
# 5            5        1      m               0        False      4
# 6            6      225      m               0        False     14
# 7            7       89      m               0        False     26
# 8            8       41      f               0        False      9
# 9            9        3      m               0        False      4
# 10          10        1      m               0        False      4
# 11          11      191      f               0        False     31
# 12          12       32      f               7        False      7
# ...

# %%
b=pd.read_csv('hjmd.csv')

# %%
c=b['Code'].astype('str').tolist()

# %%
len(c)
# Out:
# 113

# %%
c[0:20]
# Out:
# ['1266873830',
#  '1338252410',
#  '1380262714',
#  '1550936751',
#  '1580838020',
#  '1595452017',
#  '1627718624',
#  '1682478870',
#  '1685263893',
#  '1687678704',
#  '1694831243',
#  '1737276191',
#  '1737468690',
#  '1740350792',
#  '1751120234',
#  '1769358757',
#  '1781387383',
#  '1787624284',
#  '1794349680',
#  '1796133687']

# %%
c[20:40]
# Out:
# ['1799506375',
#  '1806841204',
#  '1807830442',
#  '1826562655',
#  '1842476903',
#  '1846836925',
#  '1849983497',
#  '1856181753',
#  '1864992092',
#  '1865017937',
#  '1878250733',
#  '1878496465',
#  '1888741665',
#  '1897662683',
#  '1921566117',
#  '1938073311',
#  '1945268717',
#  '1946582314',
#  '1952099555',
#  '1960465721']

# %%
c[20:40,43:50]2436672594
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-64-9c6eeee46203> in <module>()
# ----> 1 c[20:40,43:50]
#
# TypeError: list indices must be integers or slices, not tuple

# %%
c[62]
# Out:
# '2436672594'

# %%
c[100:]
# Out:
# ['5386777684',
#  '5394557775',
#  '5405993013',
#  '5496961974',
#  '5542799804',
#  '5707739917',
#  '5797537990',
#  '5960726022',
#  '6027001836',
#  '6045629846',
#  '6072469593',
#  '6290636330',
#  '6406649869']
