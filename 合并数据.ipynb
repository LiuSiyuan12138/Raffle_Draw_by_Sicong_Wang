# %%
import pandas as pd
import numpy as np

# %%
a=pd.read_excel('loser_sample//转发者抽样_带特征1.xlsx')
b=pd.read_excel('loser_sample//转发者抽样_带特征2.xlsx')
c=pd.read_excel('loser_sample//转发者抽样_带特征3.xlsx')
d=pd.read_excel('loser_sample//转发者抽样_带特征4.xlsx')
e=pd.read_excel('loser_sample//转发者抽样_带特征5.xlsx')

# %%
loser_list=[a,b,c,d,e]

# %%
res = pd.concat(loser_list,axis=0,ignore_index=True)

# %%
res=res.drop_duplicates().reset_index(drop=True)

# %%
res2=res.sample(n=200).reset_index(drop=True)

# %%
res2
# Out:
#      have_pic_count  mean_attitudes  mean_comments  mean_reposts  \
# 0                 0        1.000000       0.000000      0.000000
# 1                 1        0.000000       0.000000      0.000000
# 2                 1        0.250000       0.000000      0.000000
# 3                 0        0.000000       0.000000      0.000000
# 4                 1        0.181818       0.000000      0.000000
# 5                 0        0.000000       0.000000      0.000000
# 6                 0        0.000000       0.000000      0.000000
# 7                 0        0.000000       0.000000      0.000000
# 8                 0        0.000000       0.000000      0.000000
# 9                 3        0.181818       0.045455      0.136364
# 10                0        1.000000       0.000000      0.000000
# 11                0        0.000000       0.000000      0.000000
# 12                0        0.000000       0.000000      0.000000
# ...

# %%
res2.to_excel('转发者抽样200个.xlsx')
